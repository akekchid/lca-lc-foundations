# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on 31/08/2026")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on 31/08/2026', additional_kwargs={}, response_metadata={}, id='7b7f5aa7-a30e-4a5b-abda-0a0a971fd984'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1192, 'prompt_tokens': 1232, 'total_tokens': 2424, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DmndYV3MCklQdPwyvwyyJMwd5vjYk', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e8f6f-aa16-7fe2-bca8-0193e5484d48-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/08/2026'}, 'id': 'call_m0HAqHQay82UtEzqXi6X6fsu', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1232, 'output_tokens': 1192, 'total_tokens': 2424, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 1152}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-08-31T07:30:00.000Z",\n      "local": "2026-08-31T00:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-09-01T04:00:00.000Z",\n      "local": "2026-09-01T13:00:00.000"\n    },\n    "totalDurationInSeconds": 73800,\n    "durationInSeconds": 73800,\n    "price": 410,\n    "deepLink": "https://on.kiwi.com/3eLBmS",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "MNL",\n        "city": "Manila",\n        "cityCode": "MNL",\n        "arrival": {\n          "utc": "2026-08-31T21:30:00.000Z",\n          "local": "2026-09-01T05:30:00.000"\n        },\n        "departure": {\n          "utc": "2026-08-31T23:30:00.000Z",\n          "local": "2026-09-01T07:30:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-08-31T07:30:00.000Z",\n      "local": "2026-08-31T00:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-09-01T11:20:00.000Z",\n      "local": "2026-09-01T20:20:00.000"\n    },\n    "totalDurationInSeconds": 100200,\n    "durationInSeconds": 100200,\n    "price": 410,\n    "deepLink": "https://on.kiwi.com/y7tQRK",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "MNL",\n        "city": "Manila",\n        "cityCode": "MNL",\n        "arrival": {\n          "utc": "2026-08-31T21:30:00.000Z",\n          "local": "2026-09-01T05:30:00.000"\n        },\n        "departure": {\n          "utc": "2026-09-01T06:50:00.000Z",\n          "local": "2026-09-01T14:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-08-31T08:20:00.000Z",\n      "local": "2026-08-31T01:20:00.000"\n    },\n    "arrival": {\n      "utc": "2026-09-01T04:40:00.000Z",\n      "local": "2026-09-01T13:40:00.000"\n    },\n    "totalDurationInSeconds": 73200,\n    "durationInSeconds": 73200,\n    "price": 527,\n    "deepLink": "https://on.kiwi.com/6AtauI",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "HKG",\n        "city": "Hong Kong",\n        "cityCode": "HKG",\n        "arrival": {\n          "utc": "2026-08-31T22:15:00.000Z",\n          "local": "2026-09-01T06:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-09-01T00:15:00.000Z",\n          "local": "2026-09-01T08:15:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-08-31T08:20:00.000Z",\n      "local": "2026-08-31T01:20:00.000"\n    },\n    "arrival": {\n      "utc": "2026-09-01T04:55:00.000Z",\n      "local": "2026-09-01T13:55:00.000"\n    },\n    "totalDurationInSeconds": 74100,\n    "durationInSeconds": 74100,\n    "price": 527,\n    "deepLink": "https://on.kiwi.com/uhTSUS",\n    "currency": "EUR",\n    "layovers": [\n      {\n        "at": "HKG",\n        "city": "Hong Kong",\n        "cityCode": "HKG",\n        "arrival": {\n          "utc": "2026-08-31T22:15:00.000Z",\n          "local": "2026-09-01T06:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-09-01T00:40:00.000Z",\n          "local": "2026-09-01T08:40:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-08-31T14:03:00.000Z",\n      "local": "2026-08-31T07:03:00.000"\n    },\n    "arrival": {\n      "utc": "2026-09-01T07:00:00.000Z",\n      "local": "2026-09-01T16:00:00.000"\n    },\n    "totalDurationInSeconds": 61020,\n    "durationInSeconds": 61020,\n    "price": 532,\n    "deepLink": "https://on.k ...
#               AIMessage(content='Here are direct flight options from San Francisco (SFO) to Tokyo (NRT) on 31/08/2026:\n\nCheapest direct options\n| Route | Departure → Arrival (local) | Cabin | Return Route | Return Time | Return Cabin | Price | Deep link |\n|---|---|---|---|---|---|---:|---|\n| SFO → NRT | 31/08 13:55 → 01/09 16:30 (10h 35m) | Economy |  |  |  | 808 EUR | https://on.kiwi.com/1HIgMM |\n\nShortest duration direct options\n| Route | Departure → Arrival (local) | Cabin | Return Route | Return Time | Return Cabin | Price | Deep link |\n|---|---|---|---|---|---|---:|---|\n| SFO → NRT | 31/08 12:25 → 01/09 15:00 (10h 35m) | Economy |  |  |  | 835 EUR | https://on.kiwi.com/vLEFpa |\n| SFO → NRT | 31/08 13:55 → 01/09 16:30 (10h 35m) | Economy |  |  |  | 808 EUR | https://on.kiwi.com/1HIgMM |\n\nOther options (direct only)\n- No additional direct options found beyond the two above.\n\nRecommendation\n- Best price: 808 EUR for a direct SFO to NRT flight on 31/08/2026.\n- Quickest arrival: both direct options are the same duration (10h 35m); the 12:25 departure arrives earlier (15:00 local) but is more expensive.\n- If you prioritise a balance of price and timing, the 808 EUR option (departing 13:55 local) is the best value.\n\nHave a nice trip! Fun fact: Tokyo is famed for its mix of ancient traditions and ultra-modern life—from serene temples to the world’s busiest pedestrian crossing at Shibuya.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5254, 'prompt_tokens': 5693, 'total_tokens': 10947, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 4800, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dmndj9GJOhHwauXwMs3macUh6HPdz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e8f6f-d38b-7332-9408-5d97bcd51e54-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5693, 'output_tokens': 5254, 'total_tokens': 10947, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 4800}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are direct flight options from San Francisco (SFO) to Tokyo (NRT) on 31/08/2026:
#
# Cheapest direct options
# | Route | Departure → Arrival (local) | Cabin | Return Route | Return Time | Return Cabin | Price | Deep link |
# |---|---|---|---|---|---|---:|---|
# | SFO → NRT | 31/08 13:55 → 01/09 16:30 (10h 35m) | Economy |  |  |  | 808 EUR | https://on.kiwi.com/1HIgMM |
#
# Shortest duration direct options
# | Route | Departure → Arrival (local) | Cabin | Return Route | Return Time | Return Cabin | Price | Deep link |
# |---|---|---|---|---|---|---:|---|
# | SFO → NRT | 31/08 12:25 → 01/09 15:00 (10h 35m) | Economy |  |  |  | 835 EUR | https://on.kiwi.com/vLEFpa |
# | SFO → NRT | 31/08 13:55 → 01/09 16:30 (10h 35m) | Economy |  |  |  | 808 EUR | https://on.kiwi.com/1HIgMM |
#
# Other options (direct only)
# - No additional direct options found beyond the two above.
#
# Recommendation
# - Best price: 808 EUR for a direct SFO to NRT flight on 31/08/2026.
# - Quickest arrival: both direct options are the same duration (10h 35m); the 12:25 departure arrives earlier (15:00 local) but is more expensive.
# - If you prioritise a balance of price and timing, the 808 EUR option (departing 13:55 local) is the best value.
#
# Have a nice trip! Fun fact: Tokyo is famed for its mix of ancient traditions and ultra-modern life—from serene temples to the world’s busiest pedestrian crossing at Shibuya.
