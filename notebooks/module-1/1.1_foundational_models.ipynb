# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon is not a country or political entity, so it has no capital.\n\nIf you’re asking as a riddle, then the capital (uppercase) of the word “Moon” is M.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 823, 'prompt_tokens': 13, 'total_tokens': 836, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Di8HLgCHOChoxlpOQJoUH7JEw4vV4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e4d23-6672-7af0-8c60-5c4bcabc5978-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 823, 'total_tokens': 836, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon is not a country or political entity, so it has no capital.
#
# If you’re asking as a riddle, then the capital (uppercase) of the word “Moon” is M.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-Dh6MNxs1Lsz5g7m4SnHVgHbG9UHvA',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 810,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 768,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 823}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon has no government or population, so it has no capital. (In some science fiction, authors imagine fictional capitals for lunar settlements, but none exist in reality.)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='b31b270f-dc8f-499c-a413-7269cc1cb1e7'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or permanent population, so it has no capital. If you’re thinking of a fictional setting, some works imagine a lunar capital (e.g., names like Selene City or Lunapolis), but that would be in fiction, not reality.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 841, 'prompt_tokens': 13, 'total_tokens': 854, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Di8sxQi9WhYbbrIdTpr6dPDue3sWS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e4d46-fbac-7cd0-92ed-7abd1802dcfc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 841, 'total_tokens': 854, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or permanent population, so it has no capital. If you’re thinking of a fictional setting, some works imagine a lunar capital (e.g., names like Selene City or Lunapolis), but that would be in fiction, not reality.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='043811aa-ff57-4a9c-aebd-00060dc6faf4'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='ddc8df5f-ef89-4921-ae34-ca1d14cdfc6a', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='1fcd4590-056c-4065-8b0b-d3d5bb5f39a6'),
#               AIMessage(content='Luna City is fictional, but here’s a richer take you can use for worldbuilding or storytelling.\n\nOverview\n- A self-contained lunar metropolis built inside pressurized domes and tunnels. It governs itself through a Lunar Council with representatives from districts, research stations, and industrial hubs. Earth retains a loose diplomatic relationship, but Luna City handles most internal affairs and day-to-day governance.\n\nLocation and layout\n- Situated in the Moon’s southern polar region, near a water-ice-rich crater. The city sits atop a network of lava-tube tunnels and craters with access to solar energy, ice extraction, and communication relays.\n- The core is a ring of interconnected domes: residential districts, agriculture and hydroponics bays, a market plaza, a civic center, and a university. Outer rings house industry, power plants, and maintenance yards. Transit between zones is by pressurized tubes, small mag-lev taxis, and autonomous mining rovers.\n\nSociety and governance\n- The Lunar Council governs Luna City, with seats for:\n  - Residents (lifers and long-term workers)\n  - Scientists and engineers\n  - Industry and commerce\n  - Education and culture\n- Decision-making blends technocracy and civic participation. Laws emphasize resource sharing, safety, and responsible exploration. Citizens participate in quarterly town-halls via holographic town meetings.\n\nEconomy and technology\n- Economy centers on in-situ resource use: water ice, regolith mining, rare earths, and helium-3. Hydroponics supply fresh food; surplus crops and minerals are exported to Earth and other lunar settlements.\n- Technologies include advanced life support, radiation shielding, autonomous logistics, 3D printing of tools and components, and AI-assisted city management. Power comes from compact solar arrays and energy storage in regolith-deployed tanks.\n\nInfrastructure and daily life\n- Housing is modular: stackable apartments with flexible walls to reconfigure as families grow or shrink. Gravity is 1/6 g, so architecture includes wide corridors and furniture designed for low gravity.\n- Life support is centralized but resilient, with backups in multiple domes. Water is recycled from atmosphere and urine; air is scrubbed of CO2 and trace contaminants.\n- Transportation is mostly tube-based transit and rovers. Private flying is rare due to safety and airlock protocols; “air” is a misnomer in Luna City.\n\nCulture, education, and science\n- Culture fuses Earth nostalgia with lunar frontier pragmatism: art inspired by Earth seen through a telescope, festivals marking launches and successful harvests, and music that plays with 1/6 g acoustics.\n- Education is hands-on: a Lunar University focuses on astrogeology, in-situ resource utilization, life support engineering, and planetary science. Research stations in or around the city feed data back to the university and Earth.\n- Sports adapted to low gravity: long-distance jump events, low-gravity basketball, and lunar spelunking demonstrations in accessible lava tubes.\n\nNotable places and features\n- Civic Glass: a translucent dome where public life and government proceedings are visible to all citizens.\n- The Ice Gate: a controlled-entry ice mine where water ice is extracted and processed for consumption and agriculture.\n- Gravity Gardens: rotating hydroponics bays that simulate different microgravity environments for research and farming.\n- The Observatory Ring: a collection of telescopes and climate-controlled labs with a public viewing deck that offers a view of Earth.\n- Memorial Crater Park: a tribute to frontline workers who first settled Luna City.\n\nChallenges and opportunities\n- Resource management: balancing ice extraction with long-term sustainability; strict recycling and energy storage are crucial.\n- Radiation and micrometeoroids: heavy shielding, underground modules, and redundant life-support systems are essential.\n- Social dynamics ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is not a real place today, but a popular idea in sci‑fi settings: a sprawling capital on the Moon, home to government, culture, and commerce for the lunar colonies. Here’s a thorough, self-contained concept you can use for world-building, a novel, game setting, or screenplay. I’ve treated Luna City as the capital of a Moon polity; you can adapt the details to fit your tone (utopian, dystopian, corporate-dominated, etc.).
#
# Overview
# - Name: Luna City, capital of the Moon (the lunar polity is often called the Lunar Commonwealth/Unified Moon or similar).
# - Role: Political heart of lunar governance, primary cultural hub, and major economic center. It hosts government bodies, high-level diplomacy with Earth, major universities and research institutes, and the largest spaceport on the Moon.
# - Vibe: A mix of high-tech efficiency, crowded streets, and resilient, utilitarian architecture. Innovation sits alongside scarcity and the scars of a harsh environment.
#
# Location and geography
# - Where it sits: Near the Moon’s equator on the near side for Earth-facing visibility and communications; often perched on or inside a large crater rim to ease radiation shielding and provide dramatic topography.
# - Why the location matters: Proximity to communications relays, a stable supply of solar energy from the sunlit side, and easy slippage of supplies from Earth through the primary spaceport.
# - City form: A multi-layered, ringed city. The crater rim houses the administrative districts and observation galleries; inner rings hold living quarters, labs, and markets; a lower tier contains manufacturing, power facilities, and storage. Outer belts host agriculture domes and energy farms.
#
# History (how Luna City came to be)
# - Founding era: Early 22nd century lunar settlements linked by a federation of spacefaring states and corporations. A series of “special economic zones” evolved into a unified lunar government.
# - Independence and capital status: After a period of autonomous governance and resource-sharing disputes with Earth, the Moon formed the Lunar Commonwealth. Luna City was selected as the political capital due to its central location, infrastructure, and symbolic significance as a beacon of lunar sovereignty.
# - Recent milestones: Rapid expansion in the 22nd and 23rd centuries with new habitat domes, a major orbital elevator upgrade, and the construction of the Orbital Gateport (the spaceport for Earth-Moon traffic). Ongoing efforts focus on sustainable energy, water extraction, and advanced manufacturing.
#
# Government and politics
# - Political system: A democratic-republican federation with a Council (often called the Lunar Council or Nine Councils) and an executive office—the Moderator or Prime Director. The capital houses the Council Chambers, Presidential/Directorate offices, and the Judiciary Citadel.
# - Key institutions:
#   - Lunar Council: The legislative body, with representatives from major lunar regions and sectors (science, industry, agriculture, education, public welfare, and indigenous lunar cultures represented in some settings).
#   - Office of the Moderator: The chief executive, responsible for national security, foreign policy, and interplanetary relations.
#   - Lunar Court and Archives: Supreme judicial authority and a vast archival complex for lunar history, science data, and legal codes.
#   - Lunar Academy and Institute of Space Law: Education and policy think tanks shaping lunar science, law, and governance.
# - Earth–Moon relations: Earth remains a critical partner in trade and technology, but Luna City maintains a degree of autonomy and negotiates interplanetary treaties through the Council.
#
# Demographics and culture
# - Population: A cosmopolitan mix—Earth-born settlers, scientists, engineers, miners, and families. The capital itself may host several million residents (10–15 million in a large, multi-dome city), with a broader lunar population in outlying settlements.
# - Identity: “Lunans” or “Seleneans” who value resilience, scientific curiosity, and civic responsibility. Cultural expression blends traditional Earth heritage with lunar-specific arts, including holographic theaters, regolith sculpture, and vertical-garden cuisine.
# - Daily life quirks: People work in shifts aligned to lunar cycles (to optimize solar power and life-support needs), with long “days” split into practical work blocks during the sunlit phase and maintenance downtime during the night phase. Robotics and AI handle routine maintenance, with humans focusing on design, governance, and artistry.
#
# Economy and technology
# - Main industries:
#   - Resource processing: extracting water ice, oxygen, and specialty metals from regolith; processing for life-support systems and manufacturing.
#   - High-tech manufacturing: 3D printing, advanced composites, solar cells, optics, habitat components.
#   - Research and development: labs in universities and corporate campuses, focusing on cryogenics, space biology, radiation shielding, and AI governance.
#   - Tourism and culture: guided tours of domed districts, observatories, and lunar trails.
# - Energy: A combination of solar farms on crater rims and sunlit plains, compact fusion microreactors, and energy beaming to storage networks. Energy security is a political priority due to supply-chain disruptions from Earth.
# - Trade: The spaceport and Luna City’s markets are hubs for Earth-to-Moon trade. Water and oxygen credits, rare minerals, and advanced tech are common exchange items.
#
# Infrastructure and urban design
# - Architecture: A blend of durable, modular domes and rad-shielded glass‑and‑metal towers. Habitats are often stacked in vertical districts to minimize surface exposure while maximizing usable space.
# - Transportation:
#   - Surface: Maglev-like transport in vacuum-hardened tunnels; autonomous lunar vehicles on pre-laid routes.
#   - Vertical: Elevator systems up crater walls and through central hubs.
#   - Air and space transit: The Orbital Gateport handles incoming shuttles and freight; rapid transit to Earth is common for business and diplomacy.
# - Living spaces: Mixed-use districts with residential towers, schools, clinics, markets, and parks. Some neighborhoods include “green belts” with hydroponic farms and educational observatories.
# - Infrastructure challenges: Radiation shielding, dust mitigation, thermal control, and redundancy for life-support systems. Water management and recycling are critical.
#
# Notable districts and landmarks
# - Administrative Rim: The seat of government, with the Lunar Council Chambers and Directive HQ.
# - Observatory Ring: Public and private observatories, a center for space science and public education.
# - Glass Quarter: High-end residential and cultural venues, art houses, and holographic theaters.
# - Market Basin: Commercial centers, lunar craft markets, and the main spaceport access.
# - Archives Spire: The massive data archive and research library containing lunar history, treaties, and scientific datasets.
# - Agricultural Crescent: Domed farms producing food, oxygen, and biopharma raw materials.
# - Memorial Slopes: Parks and monuments honoring lunar pioneers and space-era tragedies.
#
# Science, research, and education
# - Leading institutions: Lunar Academy, Institute of Space Law, Center for Regolith Engineering, and multiple university campuses embedded in the city.
# - Research strengths: Radiation shielding, closed-loop life-support systems, 3D‑printed habitats, hydroponics, energy storage, AI governance, and human-robot collaboration.
# - Public science culture: Open labs, citizen science programs, and regular space-heritage festivals that blend education with cultural performance.
#
# Security, governance, and law
# - Law enforcement: Lunar Constabulary supported by automated drones, boundary enforcement around the city’s protected zones, and cyber-legal enforcement for interplanetary commerce.
# - Defense posture: Defensive space assets and patrols to deter asteroid events and space debris threats; not a warlike culture, but practical defense for vital infrastructure.
# - Civil rights: The constitution enshrines free assembly, access to education, and proportional representation for all lunar residents, with special provisions for indigenous lunar communities or historically marginalized groups (if included in your lore).
#
# Life in Luna City: a day-in-the-life snapshot
# - Morning: A commuter path in the Glass Quarter, coffee and a view of the Earth from the observatories. A student bikes on a gravity-controlled street with a slight artificial gravity feel.
# - Daytime: Lab work, governance meetings, manufacturing floor shifts, and public administration. Government drones and AI handle traffic and logistics.
# - Evening: Markets come alive; holographic performances in the Theater District; family dinners in hydroponic-dome restaurants.
# - Night: Routine maintenance on life-support systems; engineers review radiation shielding and energy grids. Some districts offer “dark sky” zones for stargazing and reflection.
#
# Story seeds and prompts (if you’re writing fiction or designing a game)
# - A political scandal unveils a data leak from the Archives Spire that reveals a long-hidden lunar treaty with Earth—how will it affect sovereignty and daily life?
# - A water-ice shipment from a polar outpost goes missing near Dock 7; a detective team uncovers a web of corporate intrigue and ecological crime.
# - An indigenous lunar community or cultural group seeks recognition and lands rights within the urban core, triggering constitutional debates.
# - A solar storm disrupts power and comms; engineers must improvise a temporary life-support and governance backup while cyber-ambients try to secure the grid.
# - A new habitat dome opens in the Agricultural Crescent, but a mysterious plant pathogen emerges that threatens lunar food supply.
#
# Variants and tone adjustments
# - Utopian governance: Emphasize transparency, public welfare, and collaborative Earth–Moon projects with high public trust.
# - Corporate city: The government is lean, and mega-corporations control most infrastructure; politics are a marketplace of influence and data.
# - Gritty frontier feel: Emphasize resource scarcity, crime, and social tension; actors operate in gray areas between law and necessity.
# - Noir mystery: Damp, shadowed corridors inside the crater rim, with a focus on investigators, backroom deals, and hidden histories.
#
# If you’d like, I can tailor Luna City to a specific tone (optimistic, noir, corporate-dominated, etc.), tighten the backstory to fit a particular time period, or build a detailed character roster and plot hooks for a novel or game. Do you want a shorter, quick-reference version or a full, publishable lore bible?
