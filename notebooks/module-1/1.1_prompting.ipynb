# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. International space law doesn’t recognize sovereignty over the Moon, so there’s no official capital city. If humans establish bases in the future, any “capital” would just be a name used by the people who run those bases, not an official designation. If you’re thinking of a fictional or humorous option, I can suggest some playful names (e.g., Luna City, Selene) or point to examples from fiction.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Lunaris Prime.
#
# - Location: A ring-city perched along the terminator of a polar crater, catching the best balance of sunlight and shade.
# - Government: The Lunar Commonwealth, a technocratic federation guided by an AI-enabled planetary council.
# - Architecture: Gleaming glass-domed districts, basalt towers, and solar farms arrayed around a central core called the Dawn Gate.
# - Landmarks: The Dawn Gate, Helio Spire, and the Echo Archive, a vast data library carved into lunar basalt.
# - Culture: A high-efficiency, low-gravity society with rooftop farms, vertical gardens, and festivals celebrating solar cycles.
# - Economy: Helium-3 mining, water ice extraction, and advanced in-situ manufacturing powering orbital trade.
# - Transportation: A lunar elevator to a near-orbital hub, maglev rails, and drone-delivery corridors beneath the domes.
#
# If you want, I can tailor Lunaris Prime to a specific vibe—hard sci-fi, noir, utopian, or dystopian.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the Moon is Lunapolis.

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
# Location: Equatorial region of the Moon, Mare Tranquillitatis (Sea of Tranquility), built along a sunlit crater rim with terraced habitats and solar farms.
# Vibe: Futuristic, austere
# Economy: Helium-3 mining, lunar ice extraction, in-situ resource processing, spaceport and logistics services, automated construction and repair

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response
# Out:
# {'messages': [HumanMessage(content='What is the capital of The Moon?', additional_kwargs={}, response_metadata={}, id='76a7dbf4-62ac-4eba-94ea-9488d6606d2a'),
#   AIMessage(content='{"name":"Lunaris Prime","location":"South Pole region, rim of Shackleton Crater, Moon","vibe":"crystal-lit, multi-layered metropolis of domed districts and anti-gravity towers; governance, science, and culture under a pale, constant daylight","economy":"ice harvesting for water, helium-3 mining, in-situ lunar manufacturing, research hubs, and spaceport commerce"}', additional_kwargs={'parsed': None, 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 929, 'prompt_tokens': 193, 'total_tokens': 1122, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DiOqJB3urNLDZkULDQs5siJeMdG6d', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e50ee-f927-7471-8653-1b34c152ee6e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 193, 'output_tokens': 929, 'total_tokens': 1122, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}})],
#  'structured_response': CapitalInfo(name='Lunaris Prime', location='South Pole region, rim of Shackleton Crater, Moon', vibe='crystal-lit, multi-layered metropolis of domed districts and anti-gravity towers; governance, science, and culture under a pale, constant daylight', economy='ice harvesting for water, helium-3 mining, in-situ lunar manufacturing, research hubs, and spaceport commerce')}

# %%
response["structured_response"].name
# Out:
# 'Lunopolis'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunopolis is a city located at Near-side Mare Tranquillitatis, along the lunar terminator, built into a shielded crater rim and linked lava-tube megacities.
